# %% [markdown]
# # IMPORTACIÓ

# %%
import sys
import openchord as ocd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import holoviews as hv
hv.extension('bokeh')
import pandas as pd

# !{sys.executable} -m pip install holoviews bokeh
# !{sys.executable} -m pip install selenium
# !{sys.executable} -m pip install openchord
# Out:
# Requirement already satisfied: holoviews in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (1.21.0)
# Requirement already satisfied: bokeh in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (3.8.0)
# Requirement already satisfied: colorcet in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from holoviews) (3.1.0)
# Requirement already satisfied: numpy>=1.21 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from holoviews) (2.2.3)
# Requirement already satisfied: packaging in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from holoviews) (25.0)
# Requirement already satisfied: pandas>=1.3 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from holoviews) (2.2.3)
# Requirement already satisfied: panel>=1.0 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from holoviews) (1.8.2)
# Requirement already satisfied: param<3.0,>=2.0 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from holoviews) (2.2.1)
# Requirement already satisfied: pyviz-comms>=2.1 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from holoviews) (3.0.6)
# Requirement already satisfied: Jinja2>=2.9 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from bokeh) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from bokeh) (1.3.1)
# Requirement already satisfied: narwhals>=1.13 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from bokeh) (2.10.1)
# Requirement already satisfied: pillow>=7.1.0 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from bokeh) (11.3.0)
# Requirement already satisfied: PyYAML>=3.10 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from bokeh) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from bokeh) (6.5.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from bokeh) (2025.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from Jinja2>=2.9->bokeh) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from pandas>=1.3->holoviews) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from pandas>=1.3->holoviews) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from pandas>=1.3->holoviews) (2025.2)
# Requirement already satisfied: bleach in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from panel>=1.0->holoviews) (6.2.0)
# Requirement already satisfied: linkify-it-py in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from panel>=1.0->holoviews) (2.0.3)
# Requirement already satisfied: markdown in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from panel>=1.0->holoviews) (3.9)
# Requirement already satisfied: markdown-it-py in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from panel>=1.0->holoviews) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from panel>=1.0->holoviews) (0.5.0)
# Requirement already satisfied: requests in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from panel>=1.0->holoviews) (2.32.4)
# Requirement already satisfied: tqdm in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from panel>=1.0->holoviews) (4.67.1)
# Requirement already satisfied: typing-extensions in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from panel>=1.0->holoviews) (4.12.2)
# Requirement already satisfied: six>=1.5 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3->holoviews) (1.17.0)
# Requirement already satisfied: webencodings in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from bleach->panel>=1.0->holoviews) (0.5.1)
# Requirement already satisfied: uc-micro-py in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from linkify-it-py->panel>=1.0->holoviews) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from markdown-it-py->panel>=1.0->holoviews) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from requests->panel>=1.0->holoviews) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from requests->panel>=1.0->holoviews) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from requests->panel>=1.0->holoviews) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from requests->panel>=1.0->holoviews) (2025.8.3)
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e8b696d7-e33f-401a-8efd-8b53d5befc34'>
#   <div id="c960d536-ef0b-4fab-abb8-cba27f478544" data-root-id="e8b696d7-e33f-401a-8efd-8b53d5befc34" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"14a30af5-4cae-49fc-969f-4a7db0554d5e":{"version":"3.8.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"053fc013-a193-44d5-aa2d-cffae3694c06","attributes":{"notifications":{"type":"object","name":"Notifications","id":"eceb0830-b930-48f6-9b22-4074ecb6ca6e"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"e8b696d7-e33f-401a-8efd-8b53d5befc34"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"b42566d8-6a4e-4706-a141-9ced2c1e7a6b","attributes":{"plot_id":"e8b696d7-e33f-401a-8efd-8b53d5befc34","comm_id":"8270a3c815f24cc9b5bef07d3aecc193","client_comm_id":"815deea87dde4b1788b064b7d03c3e9c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"14a30af5-4cae-49fc-969f-4a7db0554d5e","roots":{"e8b696d7-e33f-401a-8efd-8b53d5befc34":"c960d536-ef0b-4fab-abb8-cba27f478544"},"root_ids":["e8b696d7-e33f-401a-8efd-8b53d5befc34"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.21.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.8.0">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>
# Collecting selenium
#   Downloading selenium-4.38.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.32.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting certifi>=2025.10.5 (from selenium)
#   Downloading certifi-2025.10.5-py3-none-any.whl.metadata (2.5 kB)
# Collecting typing_extensions<5.0,>=4.15.0 (from selenium)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (24.3.0)
# Collecting sortedcontainers (from trio<1.0,>=0.31.0->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (3.7)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/claraferrerrodriguez/opt/anaconda3/envs/environment_uoc20251pec1/lib/python3.13/site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.38.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 2.4 MB/s  0:00:04 eta 0:00:01
# Downloading trio-0.32.0-py3-none-any.whl (512 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, typing_extensions, outcome, certifi, trio, trio-websocket, selenium
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2━━━━━━━━━━━ 2/8 [typing_extensions]
#   Attempting uninstall: certifi0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/8 [typing_extensions]
#     Found existing installation: certifi 2025.8.3━━━━━━━━━━━━━ 2/8 [typing_extensions]
#     Uninstalling certifi-2025.8.3:━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/8 [typing_extensions]
#       Successfully uninstalled certifi-2025.8.3━━━━━━━━━━━━━━━ 2/8 [typing_extensions]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [selenium]7/8 [selenium]ocket]
# Successfully installed certifi-2025.10.5 outcome-1.3.0.post0 selenium-4.38.0 sortedcontainers-2.4.0 trio-0.32.0 trio-websocket-0.12.2 typing_extensions-4.15.0 wsproto-1.2.0

# %% [markdown]
# # CHORD CHARD

# %%
df = pd.read_csv("/Users/claraferrerrodriguez/UOC/Visualitzacio de dades/comtrade_data.csv")
df = df[['reporterISO', 'partnerISO', 'cifvalue']]
df = df.rename(columns={'reporterISO': 'source', 'partnerISO': 'target', 'cifvalue': 'value'})

df['value_mil'] = df['value'] / 1e6


countries = list(pd.unique(df[['source','target']].values.ravel()))

matrix = np.zeros((len(countries), len(countries)))
for _, row in df.iterrows():
    i = countries.index(row['source'])
    j = countries.index(row['target'])
    matrix[i,j] = row['value_mil']


fig = ocd.Chord(matrix.tolist(), labels=countries)
fig.show()

# %% [markdown]
# ## WAFFLE CHART

# %%
df_1 = pd.read_csv("/Users/claraferrerrodriguez/UOC/Visualitzacio de dades/exports_spain.csv")

# %%
df_1 = df_1[['reporterISO', 'partnerISO', 'cifvalue']]

world_total = df_1.loc[df_1["partnerISO"] == "World", "cifvalue"].values[0]
france_value = df_1.loc[df_1["partnerISO"] == "France", "cifvalue"].values[0]
rest_value = world_total - france_value

waffle_df = pd.DataFrame({
    "partner": ["France", "Rest of World"],
    "value": [france_value, rest_value]
})


waffle_df["percentage"] = waffle_df["value"] / waffle_df["value"].sum() * 100


total_squares = 100
squares_per_category = np.round(waffle_df["percentage"]).astype(int)

waffle = []
for i, count in enumerate(squares_per_category):
    waffle.extend([waffle_df["partner"][i]] * count)

#matriu
waffle_matrix = np.array(waffle).reshape((10,10))


fig, ax = plt.subplots(figsize=(6,6))
colors = plt.cm.Set3(np.linspace(0,1,len(waffle_df)))

for i in range(10):
    for j in range(10):
        idx = list(waffle_df["partner"]).index(waffle_matrix[i,j])
        ax.add_patch(
            plt.Rectangle((j, 9-i), 1, 1, facecolor=colors[idx], edgecolor='white'))

ax.set_xticks([])
ax.set_yticks([])
ax.set_xlim(0,10)
ax.set_ylim(0,10)
ax.set_title("Spain 2024 Exports: France vs Rest of World")


ax.legend(
    handles=[plt.Rectangle((0,0),1,1,color=colors[i]) for i in range(len(waffle_df))],
    labels=waffle_df["partner"].tolist(),  # ← convertir Series a list
    loc="lower center",
    bbox_to_anchor=(0.5,-0.1),
    ncol=len(waffle_df)
)

plt.show()

# %% [markdown]
# ## AREA CHART

# %%
df_2 = pd.read_csv("/Users/claraferrerrodriguez/UOC/Visualitzacio de dades/trade_flow.csv")

df_2 = df_2[['refPeriodId','cifvalue']]

df_2['year'] = pd.to_numeric(df_2['refPeriodId'], errors='coerce')
df_2['cifvalue_billions'] = df_2['cifvalue'] / 1e9


df_2 = df_2.sort_values('year')

plt.figure(figsize=(10,6))
sns.set_style("whitegrid")
sns.lineplot(data=df_2, x='year', y='cifvalue_billions', marker='o', color='skyblue')
plt.fill_between(df_2['year'], df_2['cifvalue_billions'], color='skyblue', alpha=0.4)

plt.title("Area Plot: CIF Value per Year")
plt.xlabel("Year")
plt.ylabel("CIF Value (Billion USD)")
plt.xticks(df_2['year'].unique(), rotation=45)
plt.tight_layout()
plt.show()
